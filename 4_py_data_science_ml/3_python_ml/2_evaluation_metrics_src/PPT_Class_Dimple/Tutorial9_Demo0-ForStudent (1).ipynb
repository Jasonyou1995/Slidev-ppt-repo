# %%
# !pip install scikit-learn
# !pip install yfinance
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.2.tar.gz (7.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.22.0 in /Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages (from scikit-learn) (2.3.4)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Using cached scipy-1.16.3-cp314-cp314t-macosx_14_0_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: joblib>=1.2.0 in /Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages (from scikit-learn) (1.5.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scipy-1.16.3-cp314-cp314t-macosx_14_0_x86_64.whl (23.9 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Building wheels for collected packages: scikit-learn
#   Building wheel for scikit-learn (pyproject.toml) ... done
#   Created wheel for scikit-learn: filename=scikit_learn-1.7.2-cp314-cp314t-macosx_26_0_x86_64.whl size=9113553 sha256=255bfdc5a044ee3feae3a13e9344dbee8734686e2aafbbc95d982e2d77795df5
#   Stored in directory: /Users/mac14/Library/Caches/pip/wheels/c2/32/d8/9b31248f57a70864ce36adbdd023313845f17888f81a91a21d
# Successfully built scikit-learn
# Installing collected packages: threadpoolctl, scipy, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn]━━━━━ 2/3 [scikit-learn]
# Successfully installed scikit-learn-1.7.2 scipy-1.16.3 threadpoolctl-3.6.0
# Reshimming asdf python...
# Collecting yfinance
#   Using cached yfinance-0.2.66-py2.py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pandas>=1.3.0 in /Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: requests>=2.31 in /Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages (from yfinance) (4.14.2)
# Collecting curl_cffi>=0.7 (from yfinance)
#   Using cached curl_cffi-0.13.0.tar.gz (151 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [61 lines of output]
#       Using /Users/runner/work/_temp/install/lib to store libcurl-impersonate
#       Downloading libcurl-impersonate from https://github.com/lexiforest/curl-impersonate/releases/download/v1.2.0/libcurl-impersonate-v1.2.0.x86_64-macos.tar.gz...
#       Unpacking downloaded files...
#       Traceback (most recent call last):
#         File "/Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "/Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/mac14/.asdf/installs/python/3.14.0t/lib/python3.14t/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/private/var/folders/s6/gnxyg5wj5x92b443qtfchfq00000gn/T/pip-build-env-47nn2ns9/overlay/lib/python3.14t/site-packages/setuptools/build_meta.py", line 331, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/s6/gnxyg5wj5x92b443qtfchfq00000gn/T/pip-build-env-47nn2ns9/overlay/lib/python3.14t/site-packages/setuptools/build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#           ~~~~~~~~~~~~~~^^
#         File "/private/var/folders/s6/gnxyg5wj5x92b443qtfchfq00000gn/T/pip-build-env-47nn2ns9/overlay/lib/python3.14t/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#           ~~~~^^^^^^^^^^^^^^^^
#         File "<string>", line 16, in <module>
#         File "/private/var/folders/s6/gnxyg5wj5x92b443qtfchfq00000gn/T/pip-build-env-47nn2ns9/overlay/lib/python3.14t/site-packages/setuptools/__init__.py", line 115, in setup
#           return distutils.core.setup(**attrs)
#                  ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^
#         File "/private/var/folders/s6/gnxyg5wj5x92b443qtfchfq00000gn/T/pip-build-env-47nn2ns9/overlay/lib/python3.14t/site-packages/setuptools/_distutils/core.py", line 148, in setup
#           _setup_distribution = dist = klass(attrs)
#                                        ~~~~~^^^^^^^
#         File "/private/var/folders/s6/gnxyg5wj5x92b443qtfchfq00000gn/T/pip-build-env-47nn2ns9/overlay/lib/python3.14t/site-packages/setuptools/dist.py", line 321, in __init__
#           _Distribution.__init__(self, dist_attrs)
#           ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/s6/gnxyg5wj5x92b443qtfchfq00000gn/T/pip-build-env-47nn2ns9/overlay/lib/python3.14t/site-packages/setuptools/_distutils/dist.py", line 309, in __init__
#           self.finalize_options()
#           ~~~~~~~~~~~~~~~~~~~~~^^
#         File "/private/var/folders/s6/gnxyg5wj5x92b443qtfchfq00000gn/T/pip-build-env-47nn2ns9/overlay/lib/python3.14t/site-packages/setuptools/dist.py", line 784, in finalize_options
#           ep(self)
#           ~~^^^^^^
#         File "/private/var/folders/s6/gnxyg5wj5x92b443qtfchfq00000gn/T/pip-build-env-47nn2ns9/overlay/lib/python3.14t/site-packages/setuptools/dist.py", line 804, in _finalize_setup_keywords
#           ep.load()(self, ep.name, value)
#           ~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/s6/gnxyg5wj5x92b443qtfchfq00000gn/T/pip-build-env-47nn2ns9/overlay/lib/python3.14t/site-packages/cffi/setuptools_ext.py", line 229, in cffi_modules
#           add_cffi_module(dist, cffi_module)
#           ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/s6/gnxyg5wj5x92b443qtfchfq00000gn/T/pip-build-env-47nn2ns9/overlay/lib/python3.14t/site-packages/cffi/setuptools_ext.py", line 50, in add_cffi_module
#           execfile(build_file_name, mod_vars)
#           ~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/s6/gnxyg5wj5x92b443qtfchfq00000gn/T/pip-build-env-47nn2ns9/overlay/lib/python3.14t/site-packages/cffi/setuptools_ext.py", line 26, in execfile
#           exec(code, glob, glob)
#           ~~~~^^^^^^^^^^^^^^^^^^
#         File "scripts/build.py", line 142, in <module>
#           download_libcurl()
#           ~~~~~~~~~~~~~~~~^^
#         File "scripts/build.py", line 73, in download_libcurl
#           os.makedirs(arch["libdir"], exist_ok=True)
#           ~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "<frozen os>", line 226, in makedirs
#         File "<frozen os>", line 226, in makedirs
#         File "<frozen os>", line 226, in makedirs
#         [Previous line repeated 1 more time]
#         File "<frozen os>", line 236, in makedirs
#       PermissionError: [Errno 13] Permission denied: '/Users/runner'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'curl_cffi' when getting requirements to build wheel

# %%
# --- Imports ---
# We import the necessary libraries for our analysis.
# yfinance: To download financial data from Yahoo Finance.
# pandas: For data manipulation and analysis.
# scikit-learn: For building and evaluating our machine learning model.
# numpy: For numerical operations, especially for calculating the root of our error metric.

import yfinance as yf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 8
#       1 # --- Imports ---
#       2 # We import the necessary libraries for our analysis.
#       3 # yfinance: To download financial data from Yahoo Finance.
#       4 # pandas: For data manipulation and analysis.
#       5 # scikit-learn: For building and evaluating our machine learning model.
#       6 # numpy: For numerical operations, especially for calculating the root of our error metric.
# ----> 8 import yfinance as yf
#       9 import pandas as pd
#      10 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
# --- Step 1: Prepare the Data ---

# We download historical stock data for Apple ('AAPL').
# The `auto_adjust=True` parameter is a best practice. It automatically adjusts the
# Open, High, Low, and Close prices for corporate actions like stock splits and dividends.
# This gives us a more accurate representation of the stock's true value over time.
data = yf.download('AAPL', start='2022-01-01', end='2023-01-01', auto_adjust=True)

# Our goal is to predict the *next* day's price.
# We create our target column 'Next_Close' by shifting the 'Close' price series up by one day.
data['Next_Close'] = data['Close'].shift(-1)

# This shift creates a `NaN` (Not a Number) value in the last row of our dataset.
# Machine learning models can't handle missing values, so we remove any rows with NaN.
data = data.dropna()

# We define our features (X) and our target (y).
# The features are the input variables our model will learn from.
# Note: When auto_adjust=True, 'Volume' is not included in the main DataFrame, so we use the available price data.
features = ['Open', 'High', 'Low', 'Close']
X = data[features]
y = data['Next_Close'] # The target is the single column we want to predict.
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# --- Step 2: Split the Data ---

# We split our dataset into a training set and a testing set.
# The model learns patterns from the training set.
# The testing set is held back to evaluate the model's performance on unseen data.
# For time-series data like stock prices, we set `shuffle=False` to ensure
# we train on the past and test on the more recent future, mimicking a real-world scenario.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# --- Step 3: Choose & Train a Model ---

# We choose a `LinearRegression` model, which is a simple and fundamental model for regression tasks.
# We create an instance of the model.
model = LinearRegression()

# We "fit" the model to our training data. This is the step where the model "learns" the
# relationship between the features (X_train) and the target (y_train).
model.fit(X_train, y_train)

print("Model training complete!")
# Out:
# Model training complete!

# %%
# --- Step 4: Evaluate the Model ---

# Now that the model is trained, we use it to make predictions on the unseen test data.
predictions = model.predict(X_test)

# We evaluate the model by comparing its `predictions` to the actual prices (`y_test`).
# Mean Squared Error (MSE) is a common metric, but its units are squared (e.g., dollars-squared).
# We calculate the Root Mean Squared Error (RMSE) to get an error metric in the same units as the price (dollars).
# A lower RMSE indicates a better fit.
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)

print(f"\nModel Evaluation on Test Data:")
print(f"Root Mean Squared Error (RMSE): ${rmse:.2f}")


# --- Step 5: Make a Prediction ---

# Let's see how our model's prediction compares to the actual price for the last day in our test set.
# This gives us a concrete example of the model's performance.
print(f"\nExample Prediction:")
print(f"Actual Price on Last Day of Test Set: ${y_test.iloc[-1]:.2f}")
print(f"Model's Predicted Price for That Day:   ${predictions[-1]:.2f}")
# Out:
# Model Evaluation on Test Data:
# Root Mean Squared Error (RMSE): $3.64
#
# Example Prediction:
# Actual Price on Last Day of Test Set: $128.00
# Model's Predicted Price for That Day:   $128.95
