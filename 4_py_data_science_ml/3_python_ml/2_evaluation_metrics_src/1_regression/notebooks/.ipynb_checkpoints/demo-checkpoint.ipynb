# %% [markdown]
# # Regression Model Metrics (HKBU FIN7830)
#
# MAE (Mean Absolute Errors) | MSE (Mean Squared Errors) | RMSE (Root Mean Squared Errors)

# %%
import numpy as np

# %%
# Generate random data
np.random.seed(42)
N = 100
y_true = np.random.uniform(10, 30, N)
y_pred = y_true + np.random.normal(0, 2, N)

# %%
y_true
# Out:
# array([17.49080238, 29.01428613, 24.63987884, 21.97316968, 13.12037281,
#        13.11989041, 11.16167224, 27.32352292, 22.02230023, 24.16145156,
#        10.41168989, 29.39819704, 26.64885282, 14.24678221, 13.63649934,
#        13.6680902 , 16.08484486, 20.49512863, 18.63890037, 15.8245828 ,
#        22.23705789, 12.78987721, 15.84289297, 17.32723687, 19.12139968,
#        25.70351923, 13.99347564, 20.28468877, 21.84829138, 10.92900825,
#        22.15089704, 13.41048247, 11.30103186, 28.97771075, 29.31264066,
#        26.16794696, 16.09227538, 11.95344228, 23.68466053, 18.80304987,
#        12.4407647 , 19.9035382 , 10.68777042, 28.18640804, 15.17559963,
#        23.25044569, 16.23422152, 20.40136042, 20.93420559, 13.69708911,
#        29.39169256, 25.50265647, 28.78997883, 27.89654701, 21.95799958,
#        28.4374847 , 11.76985004, 13.91965725, 10.90454578, 16.50660662,
#        17.77354579, 15.42698064, 26.57475018, 17.13506653, 15.61869019,
# ...

# %%
y_pred
# Out:
# array([17.66489651, 28.41627143, 24.82340039, 17.99803185, 12.68102903,
#        13.83411555, 14.11746033, 26.28698248, 20.40531303, 23.15793747,
#        12.24249412, 30.05569926, 25.58933241, 15.27331708, 13.83065444,
#        15.60538018, 14.68073867, 19.83980434, 17.85468407, 12.89755291,
#        22.82929845, 13.31198776, 15.85311988, 16.8580626 , 16.2906582 ,
#        24.86222858, 13.30804661, 18.68013423, 21.52571995, 11.73710997,
#        25.92326884, 13.7596381 , 11.81613264, 28.82881891, 25.47509823,
#        26.11491921, 16.2127358 , 16.87992651, 23.2999386 , 19.40614456,
#        12.37134116, 17.56618213, 12.97341605, 29.69027411, 16.75766353,
#        21.43167078, 19.03981014, 17.5976583 , 22.10791977, 18.07800036,
#        27.41061991, 24.37006101, 28.98928156, 26.8895957 , 18.85667271,
#        28.57461065,  9.64524261, 14.86684211,  9.06569731, 19.60647543,
#        16.20703921, 14.7828576 , 28.20178462, 14.6733379 , 16.07361006,
# ...
